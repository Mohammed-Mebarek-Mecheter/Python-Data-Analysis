# %%
import numpy as np

# %%
data = np.genfromtxt("pokemon.csv"
                        ,skip_header=1
                        ,dtype=None
                        ,delimiter=','
                        ,encoding='utf-8')

# %%
print(data)
# Out:
# [(  1, b' Poison', b' Bulbasaur', b' Grass')
#  (  2, b' Poison', b' Ivysaur', b' Grass')
#  (  3, b' Poison', b' Venusaur', b' Grass')
#  (  6, b' Flying', b' Charizard', b' Fire')
#  ( 12, b' Flying', b' Butterfree', b' Bug')
#  ( 13, b' Poison', b' Weedle', b' Bug')
#  ( 14, b' Poison', b' Kakuna', b' Bug')
#  ( 15, b' Poison', b' Beedrill', b' Bug')
#  ( 16, b' Flying', b' Pidgey', b' Normal')
#  ( 17, b' Flying', b' Pidgeotto', b' Normal')
#  ( 18, b' Flying', b' Pidgeot', b' Normal')
#  ( 21, b' Flying', b' Spearow', b' Normal')
#  ( 22, b' Flying', b' Fearow', b' Normal')
#  ( 31, b' Ground', b' Nidoqueen', b' Poison')
#  ( 34, b' Ground', b' Nidoking', b' Poison')
#  ( 41, b' Flying', b' Zubat', b' Poison')
#  ( 42, b' Flying', b' Golbat', b' Poison')
#  ( 43, b' Poison', b' Oddish', b' Grass')
#  ( 44, b' Poison', b' Gloom', b' Grass')
#  ( 45, b' Poison', b' Vileplume', b' Grass')
#  ( 46, b' Grass', b' Paras', b' Bug')
#  ( 47, b' Grass', b' Parasect', b' Bug')
# ...
